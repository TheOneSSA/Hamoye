# %% [markdown]
# # HDSC Stage One Assessment

# %% [markdown]
# #### Author : Soumya S. Acharya

# %% [markdown]
# ### Importing Libraries and Reading Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Fuel Dataset
#
# 'Record_id' : record id
#
# 'Utility_id_ferc1': Utility id assigned by the FERC
#
# 'Report_year': year of report
#
# 'Plant_name_ferc1': the name of the plant
#
# 'Fuel_type_code_pudl': the type of fuel
#
# 'Fuel_unit': the unit of fuel
#
# 'Fuel_qty_burned': the quantity of fuel burned
#
# 'Fuel_mmbtu_per_unit': the measure of energy per unit
#
# 'fuel_cost_per_unit_burned': the fuel cost per unit burned
#
# 'Fuel_cost_per_unit_delivered': the cost of fuel delivered per unit
#
# 'fuel_cost_per_mmbtu': the cost of fuel per mmbtu

# %%
df=pd.read_csv("fuel_ferc1.csv")
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29343 non-null object
# fuel_qty_burned                 29523 non-null float64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB
# None
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# ...

# %% [markdown]
# ### Skewness and Kurtosis

# %%
#print(skew(df))
#kurtosis(df)
print(df.skew(axis=0,skipna=True))
df.kurtosis(axis=0,skipna=True)
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %% [markdown]
# ### Data Correlation

# %%
df.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %% [markdown]
# ### Analysis of Different Fuel Types

# %%
df.fuel_type_code_pudl.value_counts()
# Out:
# gas        11486
# coal        8547
# oil         8064
# nuclear      818
# waste        441
# other        167
# Name: fuel_type_code_pudl, dtype: int64

# %%
#OIL
df_oil=df[df.fuel_type_code_pudl=="oil"]
print(df_oil.info())
df_oil.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8064 entries, 14 to 29514
# Data columns (total 11 columns):
# record_id                       8064 non-null object
# utility_id_ferc1                8064 non-null int64
# report_year                     8064 non-null int64
# plant_name_ferc1                8064 non-null object
# fuel_type_code_pudl             8064 non-null object
# fuel_unit                       8043 non-null object
# fuel_qty_burned                 8064 non-null float64
# fuel_mmbtu_per_unit             8064 non-null float64
# fuel_cost_per_unit_burned       8064 non-null float64
# fuel_cost_per_unit_delivered    8064 non-null float64
# fuel_cost_per_mmbtu             8064 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 756.0+ KB
# None
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count       8064.000000  8064.000000     8.064000e+03          8064.000000
# ...

# %%
#GAS
df_gas=df[df.fuel_type_code_pudl=="gas"]
print(df_gas.info())
df_gas.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11486 entries, 4 to 29522
# Data columns (total 11 columns):
# record_id                       11486 non-null object
# utility_id_ferc1                11486 non-null int64
# report_year                     11486 non-null int64
# plant_name_ferc1                11486 non-null object
# fuel_type_code_pudl             11486 non-null object
# fuel_unit                       11433 non-null object
# fuel_qty_burned                 11486 non-null float64
# fuel_mmbtu_per_unit             11486 non-null float64
# fuel_cost_per_unit_burned       11486 non-null float64
# fuel_cost_per_unit_delivered    11486 non-null float64
# fuel_cost_per_mmbtu             11486 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.1+ MB
# None
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      11486.000000  11486.000000     1.148600e+04         11486.000000
# ...

# %%
#COAL
df_coal=df[df.fuel_type_code_pudl=="coal"]
print(df_coal.info())
df_coal.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8547 entries, 0 to 29521
# Data columns (total 11 columns):
# record_id                       8547 non-null object
# utility_id_ferc1                8547 non-null int64
# report_year                     8547 non-null int64
# plant_name_ferc1                8547 non-null object
# fuel_type_code_pudl             8547 non-null object
# fuel_unit                       8496 non-null object
# fuel_qty_burned                 8547 non-null float64
# fuel_mmbtu_per_unit             8547 non-null float64
# fuel_cost_per_unit_burned       8547 non-null float64
# fuel_cost_per_unit_delivered    8547 non-null float64
# fuel_cost_per_mmbtu             8547 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 801.3+ KB
# None
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count       8547.000000  8547.000000     8.547000e+03          8547.000000
# ...

# %%
#WASTE
df_waste=df[df.fuel_type_code_pudl=="waste"]
print(df_waste.info())
df_waste.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 49 to 29477
# Data columns (total 11 columns):
# record_id                       441 non-null object
# utility_id_ferc1                441 non-null int64
# report_year                     441 non-null int64
# plant_name_ferc1                441 non-null object
# fuel_type_code_pudl             441 non-null object
# fuel_unit                       437 non-null object
# fuel_qty_burned                 441 non-null float64
# fuel_mmbtu_per_unit             441 non-null float64
# fuel_cost_per_unit_burned       441 non-null float64
# fuel_cost_per_unit_delivered    441 non-null float64
# fuel_cost_per_mmbtu             441 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 41.3+ KB
# None
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        441.000000   441.000000       441.000000           441.000000
# ...

# %%
#OTHER
df_other=df[df.fuel_type_code_pudl=="other"]
print(df_other.info())
df_other.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 84 to 27065
# Data columns (total 11 columns):
# record_id                       167 non-null object
# utility_id_ferc1                167 non-null int64
# report_year                     167 non-null int64
# plant_name_ferc1                167 non-null object
# fuel_type_code_pudl             167 non-null object
# fuel_unit                       131 non-null object
# fuel_qty_burned                 167 non-null float64
# fuel_mmbtu_per_unit             167 non-null float64
# fuel_cost_per_unit_burned       167 non-null float64
# fuel_cost_per_unit_delivered    167 non-null float64
# fuel_cost_per_mmbtu             167 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 15.7+ KB
# None
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        167.000000   167.000000     1.670000e+02           167.000000
# ...

# %%
#NUCLEAR
df_nuclear=df[df.fuel_type_code_pudl=="nuclear"]
print(df_nuclear.info())
df_nuclear.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 818 entries, 6 to 29395
# Data columns (total 11 columns):
# record_id                       818 non-null object
# utility_id_ferc1                818 non-null int64
# report_year                     818 non-null int64
# plant_name_ferc1                818 non-null object
# fuel_type_code_pudl             818 non-null object
# fuel_unit                       803 non-null object
# fuel_qty_burned                 818 non-null float64
# fuel_mmbtu_per_unit             818 non-null float64
# fuel_cost_per_unit_burned       818 non-null float64
# fuel_cost_per_unit_delivered    818 non-null float64
# fuel_cost_per_mmbtu             818 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 76.7+ KB
# None
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        818.000000   818.000000     8.180000e+02           818.000000
# ...

# %% [markdown]
# ### Further Specified Analysis for Coal

# %%
df_coal.report_year.value_counts()
# Out:
# 1995    475
# 1994    475
# 1998    431
# 1996    431
# 1999    425
# 1997    417
# 2000    403
# 2001    363
# 2002    332
# 2007    330
# 2003    329
# 2006    327
# 2012    327
# 2005    324
# 2011    323
# 2004    322
# 2008    322
# 2013    320
# 2009    319
# 2010    316
# 2014    295
# 2015    268
# 2016    239
# 2017    223
# 2018    211
# Name: report_year, dtype: int64

# %%
df_coal[df_coal.report_year==1998].describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        431.000000        431.0     4.310000e+02           431.000000
# mean         107.663573       1998.0     2.084013e+06            21.375364
# std           61.589719          0.0     3.901800e+06             3.678854
# min            1.000000       1998.0     3.110000e+02            10.168000
# 25%           45.000000       1998.0     5.323100e+05            17.588000
# 50%          120.000000       1998.0     1.062284e+06            22.102000
# 75%          159.000000       1998.0     2.297566e+06            24.539000
# max          210.000000       1998.0     5.972131e+07            28.926390
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                 431.000000                    431.000000
# mean                   27.616234                    716.015659
# std                    10.099652                  13093.551519
# ...

# %%
df_coal[df_coal.report_year==1994].describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        475.000000        475.0     4.750000e+02           475.000000
# mean         106.168421       1994.0     1.509912e+06            21.670377
# std           61.863101          0.0     2.330985e+06             3.701267
# min            1.000000       1994.0     1.586000e+03            11.526000
# 25%           46.000000       1994.0     3.851685e+05            17.788000
# 50%          113.000000       1994.0     8.568080e+05            22.814000
# 75%          159.000000       1994.0     1.699040e+06            24.832000
# max          201.000000       1994.0     3.506326e+07            27.542000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                 475.000000                    475.000000
# mean                   31.546467                    124.663939
# std                    10.659393                   2068.684797
# ...

# %% [markdown]
# ### Year-wise Analysis of Fuel cost per unit delivered

# %%
df[df.report_year==1996].fuel_cost_per_unit_delivered.describe()
# Out:
# count    1.088000e+03
# mean     9.196706e+03
# std      2.447674e+05
# min     -4.405000e+01
# 25%      2.935000e+00
# 50%      1.627000e+01
# 75%      3.057250e+01
# max      7.793482e+06
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
df[df.report_year==1997].fuel_cost_per_unit_delivered.describe()
# Out:
# count    1.094000e+03
# mean     1.114020e+04
# std      2.569459e+05
# min     -3.897200e+01
# 25%      2.946500e+00
# 50%      1.445150e+01
# 75%      2.910400e+01
# max      7.964521e+06
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
df[df.report_year==2018].fuel_cost_per_unit_delivered.describe()
# Out:
# count       951.000000
# mean        499.269966
# std        8976.783325
# min           0.000000
# 25%           3.330000
# 50%           5.840000
# 75%          70.439000
# max      245652.000000
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
df[df.report_year==2004].fuel_cost_per_unit_delivered.describe()
# Out:
# count      1192.000000
# mean        139.524275
# std        3848.790040
# min        -313.410000
# 25%           6.515000
# 50%          20.900000
# 75%          45.840250
# max      132884.000000
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
df[df.report_year==2009].fuel_cost_per_unit_delivered.describe()
# Out:
# count      1222.000000
# mean        652.694163
# std       20888.844544
# min           0.000000
# 25%           5.385500
# 50%          26.612000
# 75%          71.459500
# max      730166.000000
# Name: fuel_cost_per_unit_delivered, dtype: float64
